# %% [markdown]
# # Extract metadata from image (No need)

# %%
pip install exif
# Out:
# ...
#      |████████████████████████████████| 71kB 5.5MB/s
# ...

# %%
from exif import Image
with open('zidane.jpg', 'rb') as image_file:
  my_image = Image(image_file)

  my_image.light_source  = 2
  my_image.mytag  = "qwe123"
  print(my_image.list_all())
  print(my_image.light_source)

# with open('modified_image.jpg', 'wb') as new_image_file:
#   new_image_file.write(my_image.get_file())
# Out:
# ['_exif_ifd_pointer', '_gps_ifd_pointer', 'light_source']
# LightSource.FLUORESCENT

# %%
from PIL import Image
from PIL.ExifTags import TAGS
  
# open the image
image_file = "zidane.jpg"
with open('zidane.jpg', 'rb') as image_file:
  image = Image("zidane.jpg")
  
# extracting the exif metadata
exifdata = image.getexif()
print(exifdata)
exifdata.setdefault("qwe","123")
print(exifdata)  
# image.save()
# looping through all the tags present in exifdata
for tagid in exifdata:
      
    # getting the tag name instead of tag id
    tagname = TAGS.get(tagid, tagid)
  
    # passing the tagid to get its respective value
    value = exifdata.get(tagid)

    
    
    # printing the final result
    print(f"{tagname:25}: {value}")

with open('modified_image.jpg', 'wb') as new_image_file:
  new_image_file.write(image.get_file())

# %%
# Photo metadata is a set of data describing and providing information about rights and administration of an image.

#importing os module
import os
from PIL import Image
# Importing Pillow Python Imaging Library:that adds support for opening, manipulating, and saving many different image file formats.
from PIL.ExifTags import TAGS
# importing required modules

#print(TAGS) checking if libraries are imported or not which basically returns a key value pairs of all the metadata.

#Enter your Image here
image_file = 'zidane.jpg'   # This image is copyrighted under © 2010 Hartswood Films.
                         
# on execution an object of Image type is returned and stored in image_file variable.

image = Image.open(image_file)

# raise an IOError if file cannot be found,or the image cannot be opened.

# dictionary to store metadata keys and value pairs.
exif = {}


print(image._getexif())
# iterating over the dictionary 
for tag, value in image._getexif().items():

#extarcting all the metadata as key and value pairs and converting them from numerical value to string values
    if tag in TAGS:
        exif[TAGS[tag]] = value

#checking if image is copyrighted      
try:
    if 'Copyright' in exif:
        print("Image is Copyrighted, by ", exif['Copyright'])
except KeyError:
    pass

print()
print("Displaying all the metadatas of the image: \n")
print(exif)

# %% [markdown]
# # Import libs

# %%
# !nvidia-smi
# Out:
# Mon Mar 15 06:54:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 708.0MB 25kB/s
# ...
#      |████████████████████████████████| 5.9MB 63.8MB/s
# ...
# ERROR: torchtext 0.9.0 has requirement torch==1.8.0, but you'll have torch 1.6.0+cu101 which is incompatible.
# ...
#   Found existing installation: torch 1.8.0+cu101
#     Uninstalling torch-1.8.0+cu101:
#       Successfully uninstalled torch-1.8.0+cu101
#   Found existing installation: torchvision 0.9.0+cu101
#     Uninstalling torchvision-0.9.0+cu101:
#       Successfully uninstalled torchvision-0.9.0+cu101
# ...

# %%
import torch
torch.__version__
# Out:
# '1.8.1+cu101'

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Установка зависимостей из yolov5
# !pip install -r /content/drive/MyDrive/queue_count/yolov5/requirements.txt

# %%
# Устанавливаем зависимости сервера Университета
# !wget 'https://drive.google.com/uc?export=download&confirm=no_antivirus&id=1xBMiEYu-s-3Ifbn7sjp512Bvsb8eK2x0' -O 'reqs.txt'
# Поправить dataclasses==0.7; python_version<"3.7"
# !pip install -r reqs.txt 
# ПРОВЕРЕНО

# %% [markdown]
# # Export state_dict to torch 1.6

# %%
# %cd /content/drive/MyDrive/queue_count/yolov5

# %%
import hubconf

model = hubconf.create(name='yolov5l', pretrained=True, channels=3, classes=80, autoshape=True)

# %% [markdown]
# # Run inference on images and torch 1.6

# %%
# %cd /content/drive/MyDrive/queue_count/yolov5
# Out:
# /content/drive/MyDrive/queue_count/yolov5

# %%
import torch
import numpy as np
from PIL import Image
import hubconf

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

model = hubconf.create_new(name='yolov5l', pretrained=True, channels=3, classes=80, autoshape=True)
model.names = ['person','bicycle','car','motorcycle','airplane','bus','train','truck','boat','traffic light','fire hydrant','stop sign','parking meter','bench','bird','cat','dog','horse','sheep','cow','elephant','bear','zebra','giraffe','backpack','umbrella','handbag','tie','suitcase','frisbee','skis','snowboard','sports ball','kite','baseball bat','baseball glove','skateboard','surfboard','tennis racket','bottle','wine glass','cup','fork','knife','spoon','bowl','banana','apple','sandwich','orange','broccoli','carrot','hot dog','pizza','donut','cake','chair','couch','potted plant','bed','dining table','toilet','tv','laptop','mouse','remote','keyboard','cell phone','microwave','oven','toaster','sink','refrigerator','book','clock','vase','scissors','teddy bear','hair drier','toothbrush']
model.classes = [0]
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
# ...

# %%
im = Image.open('/content/drive/MyDrive/queue_count/imgs/girls1.jpg')
print(im.size)
imgs = [im]

# Inference
results = model(imgs)

# Results
results.print()  
results.save()  # or .show()
res = np.array(results.render()).reshape(576,1100, 3)
print(results.print()) 
print(len(results.pred[0]))
plt.imshow(res)
plt.show()
# Out:
# (1100, 576)
# y =  tensor([[[8.25274e+00, 4.26665e+00, 1.65527e+01,  ..., 5.81195e-04, 2.93103e-04, 3.43347e-04],
#          [1.21424e+01, 4.22198e+00, 2.33740e+01,  ..., 4.90076e-04, 3.10570e-04, 3.52041e-04],
#          [1.98581e+01, 4.61374e+00, 2.25668e+01,  ..., 1.29894e-03, 3.63345e-04, 5.96850e-04],
#          ...,
#          [5.59471e+02, 3.26470e+02, 4.08916e+02,  ..., 3.85101e-03, 1.11550e-03, 1.40217e-03],
#          [5.89826e+02, 3.28336e+02, 2.86895e+02,  ..., 3.90907e-03, 1.58834e-03, 2.42076e-03],
#          [6.24668e+02, 3.35430e+02, 2.50205e+02,  ..., 6.52923e-03, 1.57138e-03, 2.49148e-03]]])
# y nms =  [tensor([[ 22.16581,  53.23190, 123.35498, 330.64975,   0.94160,   0.00000],
#         [527.59174,  26.31042, 615.96637, 325.80566,   0.93853,   0.00000],
#         [370.58429,  49.39609, 464.48987, 314.10599,   0.93586,   0.00000],
#         [262.97412,  73.79298, 337.38867, 310.39001,   0.93510,   0.00000],
# ...

# %%
im = Image.open('/content/drive/MyDrive/queue_count/imgs/zidane.jpg')
print(im.size)
imgs = [im]

# Inference
results = model(imgs)

# Results
results.print()  
results.save()  # or .show()
res = np.array(results.render()).reshape(720,1280, 3)
print(results.print()) 
print(len(results.pred[0]))
plt.imshow(res)
plt.show()
# Out:
# (1280, 720)
# y =  tensor([[[7.13079e+00, 5.40671e+00, 1.50164e+01,  ..., 2.45142e-03, 7.45738e-04, 1.38551e-03],
#          [1.47407e+01, 5.65020e+00, 2.96834e+01,  ..., 2.41909e-03, 8.22450e-04, 1.15806e-03],
#          [1.66002e+01, 5.59001e+00, 3.39120e+01,  ..., 2.52634e-03, 7.42637e-04, 9.93320e-04],
#          ...,
#          [5.71379e+02, 3.56965e+02, 2.11259e+02,  ..., 6.46565e-03, 3.55325e-03, 3.50857e-03],
#          [5.90933e+02, 3.49368e+02, 1.27647e+02,  ..., 3.68642e-03, 2.13540e-03, 2.05247e-03],
#          [6.15899e+02, 3.62681e+02, 1.68968e+02,  ..., 3.16292e-03, 2.13342e-03, 2.21758e-03]]])
# y nms =  [tensor([[3.72910e+02, 3.31710e+01, 5.73863e+02, 3.67219e+02, 9.33433e-01, 0.00000e+00],
#         [6.44810e+01, 1.09965e+02, 5.34621e+02, 3.68375e+02, 7.17199e-01, 0.00000e+00],
#         [5.47942e+02, 2.00611e+02, 6.40145e+02, 3.69200e+02, 4.68034e-01, 0.00000e+00]])]
# ...

# %%
im = Image.open('/content/drive/MyDrive/queue_count/imgs/people1.jpg')
print(im.size)
imgs = [im]

# Inference
results = model(imgs)

# Results
results.print()  
results.save()  # or .show()
res = np.array(results.render()).reshape(1280,1920, 3)
print(results.print()) 
print(len(results.pred[0]))
plt.imshow(res)
plt.show()
# Out:
# (1920, 1280)
# y =  tensor([[[4.92483e+00, 3.21676e+00, 1.30021e+01,  ..., 9.81668e-04, 6.29182e-04, 1.10920e-03],
#          [9.88923e+00, 3.95211e+00, 2.16927e+01,  ..., 9.38367e-04, 6.41763e-04, 9.78672e-04],
#          [1.68853e+01, 3.03953e+00, 2.77195e+01,  ..., 1.27302e-03, 6.21634e-04, 1.03005e-03],
#          ...,
#          [5.65341e+02, 4.22666e+02, 1.93166e+02,  ..., 6.00059e-03, 1.42383e-03, 2.37584e-03],
#          [5.86806e+02, 4.18927e+02, 1.61250e+02,  ..., 6.13690e-03, 1.53495e-03, 2.78128e-03],
#          [6.20191e+02, 4.26407e+02, 1.91449e+02,  ..., 1.05800e-02, 1.99255e-03, 3.76534e-03]]])
# y nms =  [tensor([[1.44313e+02, 1.73068e+02, 2.54196e+02, 4.21603e+02, 9.59491e-01, 0.00000e+00],
#         [2.42009e+02, 1.32777e+02, 3.40834e+02, 4.11043e+02, 9.44397e-01, 0.00000e+00],
#         [5.14472e+02, 1.37451e+02, 6.07309e+02, 3.75637e+02, 9.34767e-01, 0.00000e+00],
#         [1.61986e+01, 1.20469e+02, 1.29013e+02, 3.73479e+02, 9.13625e-01, 0.00000e+00],
# ...

# %% [markdown]
# # Run inference on videos and torch 1.6

# %%
import time
from IPython.display import HTML, display
from base64 import b64encode

test = '/content/drive/MyDrive/queue_count/test.py'
input_folder  = '/content/drive/MyDrive/queue_count/videos/source/'
output_folder = '/content/drive/MyDrive/queue_count/videos/result/'
checkpoint = '/content/drive/MyDrive/queue_count/weights/yolov5l.pt'

def do_inference(fname, show_bboxes=True):
  input_file  = f'{input_folder}{fname}.mp4'
  output_file = f'{output_folder}{fname}.webm'

  if show_bboxes:
    # !python {test} {input_file} {output_file} {checkpoint} 
  else:
    # !python {test} {input_file} {output_file} {checkpoint} --hide-bboxes

  mp4 = open(output_file,'rb').read()
  decoded_vid = "data:video/mp4;base64," + b64encode(mp4).decode()
  display(HTML(f'<video width=1000 controls><source src={decoded_vid} type="video/mp4"></video>'))

# %%
do_inference('stock1')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock2')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock3')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock4')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock5')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock6')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock7')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
do_inference('stock8')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
